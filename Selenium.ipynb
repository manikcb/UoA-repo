# %% [markdown]
# <a href="https://colab.research.google.com/github/manikcb/UoA-repo/blob/main/Selenium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install selenium

# %%
from selenium import webdriver

# %%
from selenium.webdriver.common.keys import Keys

# %%
from selenium.webdriver.common.by import By

# %%
# !apt-get update
# !apt-get install chromium-chromedriver
# !cp /usr/lib/chromium-browser/chromedriver /usr/bin

# %%
pip install webdriver-manager

# %%
from selenium import webdriver

# Set Chrome options
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--headless')  # Optional: Run Chrome in headless mode (no GUI)
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')

# Initialize ChromeDriver
driver = webdriver.Chrome(options=chrome_options)

# %%
driver.get("https://in.linkedin.com/jobs/machine-learning-jobs?position=1&pageNum=0")

# %%
html = driver.page_source
html #show the html code of the document
# Out:
# '<html lang="en"><head>\n        <meta name="pageKey" content="d_jobs_guest_search">\n          <meta name="linkedin:pageTag" content="urlType=jserp_canonical_keyword;emptyResult=false">\n        <meta name="locale" content="en_US">\n        <meta id="config" data-app-version="2.0.1386" data-call-tree-id="AAYLI4qRqh3QxxQLyGqSFw==" data-multiproduct-name="jobs-guest-frontend" data-service-name="jobs-guest-frontend" data-browser-id="61f8d09e-9e36-4558-8e08-a562c60c06cc" data-enable-page-view-heartbeat-tracking="" data-page-instance="urn:li:page:d_jobs_guest_search;PS8HiUnmQZ+q9aXcROoJ8A==" data-disable-jsbeacon-pagekey-suffix="false" data-member-id="0">\n\n        <link rel="canonical" href="https://in.linkedin.com/jobs/machine-learning-jobs">\n<!----><!---->\n<!---->\n<!---->\n<!---->\n<!---->\n          <link rel="icon" href="https://static.licdn.com/aero-v1/sc/h/al2o9zrvru7aqj8e1x2rzsrca">\n\n        <script type="text/javascript" async="" charset="utf-8" id="utag_110" src="https://
# ...

# %%
from bs4 import BeautifulSoup as bs
soup = bs(html)
print(soup.prettify()) #also show the html code of the document ;but this is readable
# Out:
# <html lang="en">
#  <head>
#   <meta content="d_jobs_guest_search" name="pageKey"/>
#   <meta content="urlType=jserp_canonical_keyword;emptyResult=false" name="linkedin:pageTag"/>
#   <meta content="en_US" name="locale"/>
#   <meta data-app-version="2.0.1386" data-browser-id="61f8d09e-9e36-4558-8e08-a562c60c06cc" data-call-tree-id="AAYLI4qRqh3QxxQLyGqSFw==" data-disable-jsbeacon-pagekey-suffix="false" data-enable-page-view-heartbeat-tracking="" data-member-id="0" data-multiproduct-name="jobs-guest-frontend" data-page-instance="urn:li:page:d_jobs_guest_search;PS8HiUnmQZ+q9aXcROoJ8A==" data-service-name="jobs-guest-frontend" id="config"/>
#   <link href="https://in.linkedin.com/jobs/machine-learning-jobs" rel="canonical"/>
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <!-- -->
#   <link href="https://static.licdn.com/aero-v1/sc/h/al2o9zrvru7aqj8e1x2rzsrca" rel="icon"/>
# ...

# %%
# Close the browser
driver.quit()
